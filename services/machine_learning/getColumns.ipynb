# %%
import pandas as pd
import glob
import sys

# %% [markdown]
# * Eventually we will want to parse from the s3 bucket

# %%
nfl = []
files = []
for filename in glob.iglob('rawDataSets/nfl/' + "**", recursive=True):
    files.append(filename)
    if ".csv" in filename:
        data = pd.read_csv(filename).columns
        for d in data:
            if d not in nfl:
                nfl.append(d)
nfl
# Out:
# ['Player Id',
#  'Name',
#  'Position',
#  'Year',
#  'Season',
#  'Week',
#  'Game Date',
#  'Home or Away',
#  'Opponent',
#  'Outcome',
#  'Score',
#  'Games Played',
#  'Games Started',
#  'Rushing Attempts',
#  'Rushing Yards',
#  'Yards Per Carry',
#  'Longest Rushing Run',
#  'Rushing TDs',
#  'Receptions',
#  'Receiving Yards',
#  'Yards Per Reception',
#  'Longest Reception',
#  'Receiving TDs',
#  'Fumbles',
#  'Fumbles Lost',
#  'Team',
#  'Yards Per Game',
#  'Receptions Longer than 20 Yards',
#  'Receptions Longer than 40 Yards',
#  'First Down Receptions',
#  'Kickoffs',
#  'Kickoff Yards',
#  'Out of Bounds Kickoffs',
#  'Yards Per Kickoff',
#  'Touchbacks',
#  'Touchback Percentage',
#  'Kickoffs Returned',
#  'Average Returned Yards',
#  'Kickoffs Resulting in TDs',
#  'On Sides Kicks',
#  'On Sides Kicks Returned',
#  'Player Code',
#  'Team Code',
#  'Last Name',
#  'First Name',
#  'Uniform Number',
#  'Class',
#  'Height',
#  'Weight',
#  'Home Town',
# ...

# %%
#files
