# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
import pandas as pd
import json
import sys

# %%
with open('data.json') as f:
    data = json.load(f)

# %%
df = pd.DataFrame.from_dict(data, orient='index')
df = df.transpose()
df
# Out:
#                          football basketball    hockey    baseball  \
# 0                        playerid  unnamed:0  playerid    playerid
# 1                            name       year     award     awardid
# 2                        position     player      year      yearid
# 3                            year        pos      lgid        lgid
# 4                          season        age      note         tie
# 5                            week         tm       pos       notes
# 6                        gamedate          g     stint      teamid
# 7                      homeoraway         gs      tmid    inseason
# 8                        opponent         mp        gp           g
# 9                         outcome        per       min           w
# 10                          score        ts%         w           l
# 11                    gamesplayed       3par         l        rank
# 12                   gamesstarted        ftr      t/ol     plyrmgr
# 13                rushingattempts       orb%       eng       stint
# 14                   rushingyards       drb%       sho         pos
# 15                  yardspercarry       trb%        ga          gs
# 16              longestrushingrun       ast%        sa     innouts
# 17                     rushingtds       stl%    postgp          po
# 18                     receptions       blk%   postmin           a
# 19                 receivingyards       tov%     postw           e
# 20              yardsperreception       usg%     postl          dp
# 21               longestreception      blanl     postt          pb
# 22                   receivingtds        ows   posteng          wp
# 23                        fumbles        dws   postsho          sb
# 24                    fumbleslost         ws    postga          cs
# 25                           team      ws/48    postsa          zr
# 26                   yardspergame     blank2         s      salary
# 27    receptionslongerthan20yards       obpm         g    park.key
# 28    receptionslongerthan40yards       dbpm       gdg   park.name
# 29            firstdownreceptions        bpm         t  park.alias
# ...                           ...        ...       ...         ...
# 6480                         None       None      None        None
# 6481                         None       None      None        None
# 6482                         None       None      None        None
# 6483                         None       None      None        None
# 6484                         None       None      None        None
# 6485                         None       None      None        None
# 6486                         None       None      None        None
# 6487                         None       None      None        None
# 6488                         None       None      None        None
# 6489                         None       None      None        None
# 6490                         None       None      None        None
# 6491                         None       None      None        None
# 6492                         None       None      None        None
# 6493                         None       None      None        None
# 6494                         None       None      None        None
# 6495                         None       None      None        None
# 6496                         None       None      None        None
# 6497                         None       None      None        None
# 6498                         None       None      None        None
# 6499                         None       None      None        None
# 6500                         None       None      None        None
# 6501                         None       None      None        None
# 6502                         None       None      None        None
# 6503                         None       None      None        None
# 6504                         None       None      None        None
# 6505                         None       None      None        None
# 6506                         None       None      None        None
# 6507                         None       None      None        None
# 6508                         None       None      None        None
# 6509                         None       None      None        None
#
#                 soccer
# 0              matchid
# 1               league
# 2             hometeam
# 3             awayteam
# 4                score
# 5        detailedscore
# 6        matchdatetime
# 7            matchdate
# 8            matchtime
# 9            scorehome
# 10           scoreaway
# 11             homeb10
# 12             homeb11
# 13             homeb12
# 14             homeb13
# 15             homeb14
# 16             homeb15
# 17             homeb16
# 18             homeb17
# 19             homeb18
# 20             homeb19
# 21            homeb110
# 22            homeb111
# 23            homeb112
# 24            homeb113
# 25            homeb114
# 26            homeb115
# 27            homeb116
# 28            homeb117
# 29            homeb118
# ...                ...
# 6480         awayb3261
# 6481         awayb3262
# 6482         awayb3263
# 6483         awayb3264
# 6484         awayb3265
# 6485         awayb3266
# 6486         awayb3267
# 6487         awayb3268
# 6488         awayb3269
# 6489         awayb3270
# 6490         awayb3271
# 6491         homescore
# 6492         awayscore
# 6493    avgoddshomewin
# 6494       avgoddsdraw
# 6495    avgoddsawaywin
# 6496    maxoddshomewin
# 6497       maxoddsdraw
# 6498    maxoddsawaywin
# 6499  topbookiehomewin
# 6500     topbookiedraw
# 6501  topbookieawaywin
# 6502      noddshomewin
# 6503         noddsdraw
# 6504      noddsawaywin
# 6505              date
# 6506        tournament
# 6507              city
# 6508           country
# 6509           neutral
#
# [6510 rows x 5 columns]

# %%
n_neighbors = 5
