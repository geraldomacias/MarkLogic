# %%
import pandas as pd
import glob
import sys

# %% [markdown]
# * Eventually we will want to parse from the s3 bucket

# %%
df = pd.read_csv('rawDataSets/nflstatistics/Basic_Stats.csv')
print(df.columns)
# Out:
# Index(['Age', 'Birth Place', 'Birthday', 'College', 'Current Status',
#        'Current Team', 'Experience', 'Height (inches)', 'High School',
#        'High School Location', 'Name', 'Number', 'Player Id', 'Position',
#        'Weight (lbs)', 'Years Played'],
#       dtype='object')

# %%
nfl = []
for filename in glob.iglob('rawDataSets/nflstatistics' + '**/*.csv', recursive=True):
    data = pd.read_csv(filename).columns
    for d in data:
        if d not in nfl:
            nfl.append(d)
nfl
# Out:
# ['Player Id',
#  'Name',
#  'Position',
#  'Year',
#  'Season',
#  'Week',
#  'Game Date',
#  'Home or Away',
#  'Opponent',
#  'Outcome',
#  'Score',
#  'Games Played',
#  'Games Started',
#  'Rushing Attempts',
#  'Rushing Yards',
#  'Yards Per Carry',
#  'Longest Rushing Run',
#  'Rushing TDs',
#  'Receptions',
#  'Receiving Yards',
#  'Yards Per Reception',
#  'Longest Reception',
#  'Receiving TDs',
#  'Fumbles',
#  'Fumbles Lost',
#  'Team',
#  'Yards Per Game',
#  'Receptions Longer than 20 Yards',
#  'Receptions Longer than 40 Yards',
#  'First Down Receptions',
#  'Kickoffs',
#  'Kickoff Yards',
#  'Out of Bounds Kickoffs',
#  'Yards Per Kickoff',
#  'Touchbacks',
#  'Touchback Percentage',
#  'Kickoffs Returned',
#  'Average Returned Yards',
#  'Kickoffs Resulting in TDs',
#  'On Sides Kicks',
#  'On Sides Kicks Returned',
#  'Rushing Attempts Per Game',
#  'Rushing Yards Per Game',
#  'Rushing First Downs',
#  'Percentage of Rushing First Downs',
# ...
